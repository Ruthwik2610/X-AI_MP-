# %% [markdown]
# # Strategy 2: Tabular Explainers
# ## Example: AIFB with Boosting and Gini/Permutation importance

# %%
import gzip
import numpy as np
import os
import os.path as osp
import random
import time

import pandas as pd
import rdflib as rdf

import time
import numpy as np

from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.inspection import permutation_importance

# %%
random.seed(0)
np.random.seed(0)

# %%
PATH_DATA = 'data/'

# %%
graph_file = 'data/Entities/aifb/raw/aifb_stripped.nt.gz'
task_file = 'data/Entities/aifb/raw/completeDataset.tsv'
train_file = 'data/Entities/aifb/raw/trainingSet.tsv'
test_file = 'data/Entities/aifb/raw/testSet.tsv'

# %% [markdown]
# ### Read graph

# %%
g = rdf.Graph()
with gzip.open(graph_file, 'rb') as f:
    g.parse(file=f, format='nt')  # type: ignore

# %% [markdown]
# ## Convert graph to table

# %%
# Initialize an empty dictionary to store the data
data = {}

# Populate the dictionary with the RDF triples
for s, p, o in g:
    if str(s) not in data:
        data[str(s)] = {}
    data[str(s)][p] = str(o)

# Convert the dictionary to a DataFrame
df = pd.DataFrame.from_dict(data, orient='index')

# Fill NaN values with an empty string for better presentation
df = df.fillna('')
df.index = df.index.astype(str)
len(df)
# Out:
# 2829

# %% [markdown]
# There are many ways how to convert a graph to a table.
#
# 1. An alternative way is described in the RGCN Paper (https://arxiv.org/pdf/1703.06103) which references an earlier paper: https://dl.acm.org/doi/pdf/10.1145/2254129.2254168
# 2. Yet another code example: https://github.com/dice-group/AutoCL/blob/53691bdd72cce7b546aed6417a9d839c3c9b9cf2/AutoCL/examples/feature%20selection%20approach/table-based%20feature%20selection/CELOE/fs_with_sklearn_on_celoe.py#L184

# %%
pd.set_option('display.max_rows', 50)

# %%
# Simplify columns and cells (simplifying rows does not work because then different rows receive the same name)
df.columns = df.columns.str.split("#").str[-1]
df.columns = df.columns.str.split("/").str[-1]
#df.index = df.index.str.split("#").str[-1]
#df.index = df.index.str.split("/").str[-1]
df = df.apply(lambda col: col.map(lambda x: x.split("#")[-1]))
df = df.apply(lambda col: col.map(lambda x: x.split("/")[-1]))

# %%
len(df)
# Out:
# 2829

# %%
pd.set_option('display.max_columns', 50)

# %%
df.head()
# Out:
#                                                           isAbout  \
# http://www.aifb.uni-karlsruhe.de/Publikationen/...   id79instance
# http://www.aifb.uni-karlsruhe.de/Publikationen/...  id137instance
# http://www.aifb.uni-karlsruhe.de/Publikationen/...  id100instance
# http://www.aifb.uni-karlsruhe.de/Publikationen/...   id30instance
# http://www.aifb.uni-karlsruhe.de/Publikationen/...  id130instance
#
#                                                              type  \
# http://www.aifb.uni-karlsruhe.de/Publikationen/...  InProceedings
# http://www.aifb.uni-karlsruhe.de/Publikationen/...    Publication
# http://www.aifb.uni-karlsruhe.de/Publikationen/...  InProceedings
# http://www.aifb.uni-karlsruhe.de/Publikationen/...        Article
# http://www.aifb.uni-karlsruhe.de/Publikationen/...    Publication
#
#                                                                                              abstract  \
# http://www.aifb.uni-karlsruhe.de/Publikationen/...  This article gives an impression how existing ...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...  Part of the theory of logic programming and no...
#
#                                                                                                 title  \
# http://www.aifb.uni-karlsruhe.de/Publikationen/...       On Visualizing the Semantic Web in MS Office
# http://www.aifb.uni-karlsruhe.de/Publikationen/...  Boosting for Text Classification with Semantic...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...                                 Semantic Wikipedia
# http://www.aifb.uni-karlsruhe.de/Publikationen/...  Anticipation and flexibility in dynamic schedu...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...  A uniform approach to logic programming semantics
#
#                                                                                             booktitle  \
# http://www.aifb.uni-karlsruhe.de/Publikationen/...  6th International Conference on Information Vi...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...  Advances in Web Mining and Web Usage Analysis,...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...  In Proceedings of the 2006 International Sympo...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
#
#                                                             author  \
# http://www.aifb.uni-karlsruhe.de/Publikationen/...    id20instance
# http://www.aifb.uni-karlsruhe.de/Publikationen/...  id2079instance
# http://www.aifb.uni-karlsruhe.de/Publikationen/...  id2097instance
# http://www.aifb.uni-karlsruhe.de/Publikationen/...    id15instance
# http://www.aifb.uni-karlsruhe.de/Publikationen/...  id2084instance
#
#                                                       hasProject  year  \
# http://www.aifb.uni-karlsruhe.de/Publikationen/...   id3instance  2002
# http://www.aifb.uni-karlsruhe.de/Publikationen/...  id44instance  2006
# http://www.aifb.uni-karlsruhe.de/Publikationen/...  id67instance  2006
# http://www.aifb.uni-karlsruhe.de/Publikationen/...                2005
# http://www.aifb.uni-karlsruhe.de/Publikationen/...                2005
#
#                                                         pages publication  \
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...    149-166
# http://www.aifb.uni-karlsruhe.de/Publikationen/...    137-138
# http://www.aifb.uni-karlsruhe.de/Publikationen/...  3103-3129
# http://www.aifb.uni-karlsruhe.de/Publikationen/...    123-159
#
#                                                    worksAtProject phone name  \
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
#
#                                                    photo fax homepage  \
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
#
#                                                        note  \
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...  REPRINT
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
#
#                                                                                series  \
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...  Lecture Notes in Computer Science
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
#
#                                                    number   month volume  \
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...   3932
# http://www.aifb.uni-karlsruhe.de/Publikationen/...         August
# http://www.aifb.uni-karlsruhe.de/Publikationen/...     15  August     43
# http://www.aifb.uni-karlsruhe.de/Publikationen/...    1-2              5
#
#                                                                                          journal  \
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...  International Journal of Production Research
# http://www.aifb.uni-karlsruhe.de/Publikationen/...      Theory and Practice of Logic Programming
#
#                                                    address dealtWithIn  \
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
#
#                                                    isWorkedOnBy type  \
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
#
#                                                    projectInfo member  \
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
#
#                                                    financedBy carriedOutBy  \
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
#
#                                                    editor inverseOf  \
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
#
#                                                    howpublished type  \
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
#
#                                                    publishes carriesOut head  \
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
#
#                                                    edition allValuesFrom  \
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
#
#                                                    onProperty isbn subClassOf  \
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
#
#                                                    chapter finances range
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...
# http://www.aifb.uni-karlsruhe.de/Publikationen/...

# %%
label_header = 'label_affiliation'
nodes_header = 'person'

# %%
train_labels_df = pd.read_csv(train_file, sep='\t')
test_labels_df = pd.read_csv(test_file, sep='\t')

# %%
# TODO: Further preprocessing, feature selection, and feature engineering to improve the evaluation results of the model?

# %% [markdown]
# ## Split dataset into training and testing sets

# %%
df = pd.get_dummies(df)
df.index = df.index.astype(str)

# %%
# Filter the DataFrame to only include valid persons
X_train = df.loc[train_labels_df['person']]
X_test = df.loc[test_labels_df['person']]

# %%
selector = VarianceThreshold(threshold=0.001)
X_train = selector.fit_transform(X_train)
X_test = selector.transform(X_test)

feature_names = df.columns[selector.get_support(indices=True)]

X_train.shape
# Out:
# (140, 486)

# %%
encoder = LabelEncoder()
y_train = encoder.fit_transform(train_labels_df['label_affiliation'])
y_test = encoder.transform(test_labels_df['label_affiliation'])

# %% [markdown]
# ## Train Model

# %%
model = GradientBoostingClassifier(n_estimators=10000, random_state=0, max_depth=1)
#model = RandomForestClassifier(n_estimators=10000, random_state=0)
#model = DecisionTreeClassifier(max_depth=20, random_state=0)
model.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(max_depth=1, n_estimators=10000, random_state=0)

# %% [markdown]
# ## Evaluate Model

# %%
accuracy = model.score(X_train, y_train)
print(f"Model accuracy Training: {accuracy}")

accuracy = model.score(X_test, y_test)
print(f"Model accuracy Test: {accuracy}")
# Out:
# Model accuracy Training: 1.0
# Model accuracy Test: 0.8611111111111112

# %% [markdown]
# ## Explain Model

# %% [markdown]
# ### Gini importance

# %%
importances_mean = model.feature_importances_
importances_std = np.std([tree.feature_importances_ for iteration in model.estimators_ for tree in iteration], axis=0)

top_n = 10
indices = np.argsort(importances_mean)[::-1][:top_n]
top_importances_mean = importances_mean[indices]
top_importances_std = importances_std[indices]

top_feature_names = np.array(feature_names)[indices]

# %%
pd.DataFrame({'top_importances_mean':top_importances_mean, 'top_importances_std':top_importances_std}, index=top_feature_names)
# Out:
#                             top_importances_mean  top_importances_std
# homepage_None                           0.066360             0.024992
# fax_+49 (721) 608 4548                  0.066345             0.078966
# worksAtProject_id2instance              0.060828             0.084255
# phone_                                  0.051146             0.110332
# phone_-                                 0.036630             0.072266
# fax_+49 (721) 608 6580                  0.033762             0.071405
# publication_                            0.026447             0.033148
# phone_+49 (721) 608 7362                0.023723             0.069828
# worksAtProject_id8instance              0.020833             0.077546
# fax_+49 (721) 693717                    0.018487             0.014141

# %% [markdown]
# ## Permutation feature importance

# %%
r = permutation_importance(model, X_test, y_test,
                           n_repeats=5,
                           random_state=0)

importances_mean = r.importances_mean
importances_std = r.importances_std

top_n = 10
indices = np.argsort(r.importances_mean)[::-1][:top_n]

top_importances_mean = importances_mean[indices]
top_importances_std = importances_std[indices]

# %%
pd.DataFrame({'top_importances_mean':top_importances_mean, 'top_importances_std':top_importances_std}, index=top_feature_names)
